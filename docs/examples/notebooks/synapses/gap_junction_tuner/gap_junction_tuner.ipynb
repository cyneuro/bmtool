# %% [markdown]
# ## Example of how to use BMTOOL gap junction tuner.
# By Gregory Glickert
#
# We first need to set up the tuner. We have general settings and connection specific parameters. We also need to say where our mechanisms and cell templates are located

# %% [markdown]
# First we will compile the modfiles

# %%
import os

# if already compiled then lets delete the folder and force a recompile
if os.path.isdir('modfiles/x86_64'):
    os.system("rm -rf modfiles/x86_64 ")
# compile the mod files
if not os.path.isdir("modfiles/x86_64"):
    os.chdir('modfiles')
    os.system("nrnivmodl")
    os.chdir("..")
# Out:
# /usr/bin/xcrun
# /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles
# /Users/gregglickert/miniconda3/envs/bmtk/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Mod files: "./AMPA_NMDA_STP.mod" "./GABA_A_STP.mod" "./Gfluct.mod" "./cadad.mod" "./cal2.mod" "./can_mig.mod" "./exp2syn_stp.mod" "./gap.mod" "./h_kole.mod" "./imCA3.mod" "./kBK.mod" "./kap_BS.mod" "./kdmc_BS.mod" "./kdrCA3.mod" "./kdr_BS.mod" "./kdrinter.mod" "./leak.mod" "./nainter.mod" "./napCA3.mod" "./natCA3.mod" "./nax_BS.mod" "./vecevent_coreneuron.mod"
#
# Creating 'arm64' directory for .o files.
#
#  -> NMODL ../GABA_A_STP.mod
#  -> Compiling mod_func.cpp
#  -> NMODL ../AMPA_NMDA_STP.mod
#  -> NMODL ../Gfluct.mod
#  -> NMODL ../cadad.mod
#  -> NMODL ../can_mig.mod
#  -> NMODL ../cal2.mod
# Warning: Default 2 of PARAMETER cao will be ignored and set by NEURON.
# Warning: Default 5e-05 of PARAMETER cai will be ignored and set by NEURON.
# Warning: Default 2 of PARAMETER cao will be ignored and set by NEURON.
# Warning: Default 5e-05 of PARAMETER cai will be ignored and set by NEURON.
#  -> NMODL ../exp2syn_stp.mod
#  -> NMODL ../gap.mod
#  -> NMODL ../h_kole.mod
#  -> NMODL ../imCA3.mod
#  -> NMODL ../kBK.mod
#  -> NMODL ../kap_BS.mod
#  -> NMODL ../kdmc_BS.mod
#  -> NMODL ../kdrCA3.mod
#  -> NMODL ../kdr_BS.mod
#  -> NMODL ../kdrinter.mod
# Warning: Default -80 of PARAMETER ek will be ignored and set by NEURON.
#  -> NMODL ../leak.mod
#  -> NMODL ../nainter.mod
#  -> NMODL ../napCA3.mod
#  -> NMODL ../natCA3.mod
# Warning: Default 45 of PARAMETER ena will be ignored and set by NEURON.
#  -> NMODL ../nax_BS.mod
#  -> NMODL ../vecevent_coreneuron.mod
#  -> Compiling AMPA_NMDA_STP.c
#  -> Compiling GABA_A_STP.c
# Notice: ARTIFICIAL_CELL is a synonym for POINT_PROCESS which hints that it
# only affects and is affected by discrete events. As such it is not
# located in a section and is not associated with an integrator
#  -> Compiling Gfluct.c
#  -> Compiling cadad.c
# Translating AMPA_NMDA_STP.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/AMPA_NMDA_STP.c
# Translating Gfluct.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/Gfluct.c
# Translating GABA_A_STP.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/GABA_A_STP.c
# Notice: This mechanism cannot be used with CVODE
# Thread Safe
# Thread Safe
# Thread Safe
# Translating can_mig.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/can_mig.c
# Translating cal2.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/cal2.c
# Translating cadad.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/cadad.c
# Thread Safe
# Thread Safe
# Thread Safe
# Translating gap.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/gap.c
# Translating h_kole.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/h_kole.c
# Translating exp2syn_stp.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/exp2syn_stp.c
# Thread Safe
# Thread Safe
# Thread Safe
# Translating imCA3.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/imCA3.c
# Translating kBK.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/kBK.c
# Translating kap_BS.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/kap_BS.c
# Thread Safe
# Thread Safe
# Thread Safe
# Translating kdmc_BS.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/kdmc_BS.c
# Translating kdrCA3.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/kdrCA3.c
# Thread Safe
# Thread Safe
# Translating kdr_BS.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/kdr_BS.c
# Translating kdrinter.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/kdrinter.c
# Thread Safe
# Thread Safe
# Translating leak.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/leak.c
# Translating nainter.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/nainter.c
# Thread Safe
# Thread Safe
# Translating natCA3.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/natCA3.c
# Translating napCA3.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/napCA3.c
# Thread Safe
# Thread Safe
# Translating nax_BS.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/nax_BS.c
# Translating vecevent_coreneuron.mod into /Users/gregglickert/Documents/GitHub/bmtool/docs/examples/notebooks/synapses/gap_junction_tuner/modfiles/arm64/vecevent_coreneuron.c
# Thread Safe
# Thread Safe
# Gfluct.cAMPA_NMDA_STP.c:GABA_A_STP.ccadad.c::4342::181842: :warning: 18a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]:
#  warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
# :: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
# 42:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    42    | 42         |     e42 | x        t eerxnt edr   n 43d | o        u belxet e*rgne tdaorugbolubel e* g*egteatragr(g)(;)
# ;
# |                               ^|
#                         ^
#         ( e);
#       |                         ^x
# tern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17/Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:   /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h15: | 15#:d17::  note: note: expanded from macro 'getarg'expanded from macro 'getarg'
#
# e17f:i   n15e |  #g enote: texpanded from macro 'getarg'a
# r   g15  | d#ed    hoc_gfeifne getaertga ri15 | #defin ehgn getarog
#         | h                ^o
# c_getac_geter getarga r gh
# o      c| _                ^g
# egt
# arg
#       |                 ^
# |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:/Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:/Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:1616: note: 16conflicting prototype is here
# : /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.hnote:    :49:conflicting prototype is here
#    49 | e  | 49e:x16t:e rnote: nconflicting prototype is here
# dxoub   lnote: econflicting prototype is here*
#  geta   r49g | (t49int);
#       | eexte | renx tdeorunb ldeo*u                ^ge
# targ(/Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.hi:n15t:r17n:  dnote: oexpanded from macro 'getarg')blue*b l
# e   *15 | #;de
# fgi       | g               ^e
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15ne:targ(ei tgetarg  nth)o;c
# _      gaetarg
#       |                 ^17
# | : r               ^
# note: /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:expanded from macro 'getarg'15
# :17:g note: expanded from macro 'getarg'
#    15 | #(d   e15f | i#ine gedefine tgaertga r gn  hohco_cg_egteatrg
#       |                 ^
# t);
#       a| r               ^g
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#
#       |                 ^
#    15 | #define getarg  hoc_getarg
#       |                 ^
# GABA_A_STP.c:356:32: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
# AMPA_NMDA_STP.c:  414356: | 32 :  iwarning: fa function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
# (_tsav > t)  {414  | e x tiefr n( _cthsaarv*  >h otc)_{o bejxetcetr_nn acmhea(r)*;  hhoocc__oebxjeeccetr_rnoarm(eh(o)c;_ ohbojce_cetx_encaemrer(o_rp(nhto-c>_oobb)j,e c"t:_Envaemnet( _aprnrti-v>eodb )o,u t" :oEfv eonrtd earr.r iMvuesdt  ocuatl lo fP aorradlelre.l CMounstt call ParallelContext.set_meaxstep xAtF.TsEeRt _amsasigning minixmum NetCsotne.pdelay") AFTER assign;ing m}i
# n      i| m                               ^u
# m NetCon.delay");}/Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h
# :      46:14: note: |                                ^
# conflicting prototype is here
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:46   :14: note: 46conflicting prototype is here | exte
# rn char*   46 | ext ehronc_object_ nacmhea(rO*b jheocct_*o)b;j
# e      c| t             ^_
# name(Object*);
#       |              ^
# 1 warning generated.
# 2 warnings generated.
# 1 warning generated.
# 2 warnings generated.
# can_mig.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    43 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# exp2syn_stp.c:42:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    42 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# exp2syn_stp.c:343:32: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#   343 |   if (_tsav > t){ extern char* hoc_object_name(); hoc_execcal2.ce:r43r:o18r:( hwarning: oa function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]c
# _object_n   a43m | e        ( _pnt->ob), ":Event arrived out of order. Must call ParallelContext.set_maxstep AFTER assigning minimum NetCon.delay");}
#       |                                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:46:14: note: conflicting prototype is here
#    46 | extern char* hoc_object_name(Object*);
#       |              ^
# gap.c:41:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    41 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# 1 warning generated.
# 2 warnings generated.
# 1 warning generated.
# 1 warning generated.
# h_kole.c:42:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    42 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# imCA3.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    43 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# kBK.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    43 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# kap_BS.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    43 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# 1 warning generated.
# 1 warning generated.
#  -> Compiling cal2.c
#  -> Compiling can_mig.c
#  -> Compiling exp2syn_stp.c
#  -> Compiling gap.c
#  -> Compiling h_kole.c
#  -> Compiling imCA3.c
#  -> Compiling kBK.c
#  -> Compiling kap_BS.c
#  -> Compiling kdmc_BS.c
#  -> Compiling kdrCA3.c
# 1 warning generated.
# 1 warning generated.
# kdmc_BS.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    43 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# kdrCA3.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    43 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# kdrinter.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    43 |          extern double *getarg();
#       |                         ^
# kdr_BS.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    43 | /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h        : 15e:x17t:e rnote: nexpanded from macro 'getarg'
# dou   b15l | e# d*egfeitnaer gg(e)t;a
# r      g|                          ^
# hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h#:d49e:f16i:n enote:  conflicting prototype is hereg
# eta   r49g |  e xhtoecr_ng edtoaurbgl
# e      *|                  ^g
# etarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:/Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h17:: note: expanded from macro 'getarg'
# 49   :1516 | :# dnote: econflicting prototype is heref
# ine    49g | eetxatregr n  hdoocu_bgleetarg
# * getar      g(int);
#       |                ^
# |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# leak.c:41:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    41 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# nainter.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    43 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# napCA3.c:44:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
# natCA3.c:43:18:    warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
# 44    |          exte43 |          extern doublre *getarg();
#       |                         ^
# n doub/Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17:l note: expanded from macro 'getarg'
# e *   g15e | t#adregf(i)n;e
#        g| etarg                         ^
# hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h   :4915 | exte:rn doubl17e:*  note: gexpanded from macro 'getarg'e
# targ(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #def   i15n | e# dgeeftianreg  g hoce_tgetarga
# r      g|                  ^
# hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
#  -> Compiling kdr_BS.c
#  -> Compiling kdrinter.c
#  -> Compiling leak.c
#  -> Compiling nainter.c
#  -> Compiling napCA3.c
#  -> Compiling natCA3.c
#  -> Compiling nax_BS.c
#  -> Compiling vecevent_coreneuron.c
# nax_BS.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    43 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# vecevent_coreneuron.c:43:18: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#    43 |          extern double *getarg();
#       |                         ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:49:16: note: conflicting prototype is here
#    49 | extern double* getarg(int);
#       |                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/hocdec.h:15:17: note: expanded from macro 'getarg'
#    15 | #define getarg  hoc_getarg
#       |                 ^
# vecevent_coreneuron.c:242:32: warning: a function declaration without a prototype is deprecated in all versions of C and is treated as a zero-parameter prototype in C23, conflicting with a previous declaration [-Wdeprecated-non-prototype]
#   242 |   if (_tsav > t){ extern char* hoc_object_name(); hoc_execerror(hoc_object_name(_pnt->ob), ":Event arrived out of order. Must call ParallelContext.set_maxstep AFTER assigning minimum NetCon.delay");}
#       |                                ^
# /Users/gregglickert/miniconda3/envs/bmtk/lib/python3.11/site-packages/neuron/.data/include/oc_ansi.h:46:14: note: conflicting prototype is here
#    46 | extern char* hoc_object_name(Object*);
#       |              ^
# 1 warning generated.
# 2 warnings generated.
#  => LINKING shared library ./libnrnmech.dylib
#  => LINKING executable ./special LDFLAGS are:
# Successfully created arm64/special
# ld: warning: ignoring duplicate libraries: '-lnrnmech'

# %% [markdown]
# ## initialize tuner

# %%
from bmtool.synapses import GapJunctionTuner
# %matplotlib inline

mechanisms_dir = 'modfiles'
templates_file = 'templates.hoc'

general_settings = {
    'tstart': 500., # when the current clamp starts
    'tdur': 500.,    # Dur of the current clamp
    'dt': 0.025, # simulation dt
    'celsius': 20 # temp of sim
}

conn_type_settings = {
    'FSI_gap': {
        'cell': 'FSI_Cell', #template name 
        'iclamp_amp' : -0.01, # nA what amp to stim cell at
        'sec_x': 0.5, # location of syn
        'sec_id': 0,  # location of syn
        "level_of_detail": "gap", # which synaptic mech to use
    }
}

tuner = GapJunctionTuner(mechanisms_dir=mechanisms_dir,templates_dir=templates_file,
                         general_settings=general_settings,conn_type_settings=conn_type_settings['FSI_gap'])
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.

# %% [markdown]
# We can then manually tune using the run.model method

# %% [markdown]
# ## InteractiveTuner()

# %%
tuner.InteractiveTuner()
# Out:
# VBox(children=(Button(button_style='primary', description='Run', icon='history', style=ButtonStyle()), FloatLo…
# Output()

# %% [markdown]
# ## GapJunctionOptimizer
# While we can manually tune the coupling coefficient since there is only one parameter that we are tuning we can optimize and find the best resistance!

# %%
from bmtool.synapses import GapJunctionOptimizer

# Create optimizer
optimizer = GapJunctionOptimizer(tuner)

# Optimize for a target coupling coefficient
target_cc = 0.37  # Example target coupling coefficient
result = optimizer.optimize_resistance(
    target_cc=target_cc,
    resistance_bounds=(1e-4, 1e-2)  # Min and max resistance values to try
)

# Plot optimization results
optimizer.plot_optimization_results(result)

# %% [markdown]
# ## parameter sweep
# We can also perform a parameter sweep to see the relationship between resistance and coupling coefficient

# %%
import matplotlib.pyplot as plt
import numpy as np

resistance_range = np.logspace(-4, -2, 20)  # 20 points between 1e-4 and 1e-2
sweep_results = optimizer.parameter_sweep(resistance_range)

# Plot sweep results
plt.figure(figsize=(8, 6))
plt.semilogx(sweep_results['resistance'], sweep_results['coupling_coefficient'], 'o-')
plt.xlabel('Resistance')
plt.ylabel('Coupling Coefficient')
plt.title('Resistance vs Coupling Coefficient')
plt.grid(True)
plt.show()
# Out:
# Sweeping resistance values:   0%|          | 0/20 [00:00<?, ?it/s]
